# %%
from sklearn.datasets import make_regression

x, y = make_regression(n_samples=100, n_features=1, noise=20)

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.show()

# %%
import numpy as np

x = np.interp(x, (x.min(), x.max()), (20, 80))
y = np.interp(y, (y.min(), y.max()), (100, 800))

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.xlabel('Square Meters')
plt.ylabel('Price (k)')
plt.show()

# %%
x = np.hstack((np.ones(shape=(len(x), 1)), x))

# %% [markdown]
# $$\theta_{LS} = (\mathbf{X}^T\mathbf{X})^{-1}\mathbf{X}^T\mathbf{y}$$

# %%
ls = np.linalg.inv(x.T.dot(x)).dot(x.T).dot(y)

# %%
y_hat = x.dot(ls)
y_hat
# Out:
# array([271.23144518, 509.10414954, 562.13669453, 243.89763448,
#        560.27906014, 443.15903451, 677.53171724, 630.17018807,
#        452.56089375, 393.0812335 , 481.64790771, 215.44090815,
#        419.70175571, 693.84989041, 524.64801553, 488.85000539,
#        538.60787372, 324.5157363 , 486.78034053, 580.91582448,
#        452.87299389, 457.50165561, 438.50040821, 429.4490919 ,
#        762.9966062 , 602.30817967, 490.06232166, 397.64908051,
#        583.55627741, 627.99611631, 502.78847972, 317.2069229 ,
#         70.76213107, 441.98241363, 558.53034748, 491.80555595,
#        487.49747518, 532.33272689, 308.52664237, 470.4180776 ,
#        411.4510925 , 622.06388552, 453.26576866, 511.52886938,
#        555.5622187 , 448.2122219 , 438.82241886, 746.92303812,
#        445.5487035 , 396.66580111, 335.63458995, 503.39081322,
#        466.57743469, 533.92782669, 388.64801304, 362.27934594,
#        263.63780672, 162.35068949, 440.63973541, 545.7447858 ,
#        581.35694916, 418.75492911, 293.47758988, 531.89011945,
#        488.40925168, 503.41635855, 615.52832899, 470.16202775,
#        562.90656175, 451.3464078 , 393.87070745, 609.90207519,
#        471.96051101, 587.900267  , 616.90845707, 453.56726711,
#        453.41488832, 503.31654559, 565.3766648 , 415.17761538,
#        617.42614924, 285.82401728, 487.64505546, 785.98191939,
#        712.25678342, 455.78329713, 296.6902942 , 768.37157786,
#        478.0736907 , 284.54654798, 524.2156571 , 276.90268939,
#        428.1902868 , 634.53267965, 392.77440265, 698.15627851,
#        344.30501126, 557.16574481, 465.0785406 , 394.80444718])

# %%
mse = np.mean((y.flatten() - y_hat)**2)
mse
# Out:
# 570.4413180452576

# %%
plt.plot(x[:,1], y_hat, c='g', label='Model')
plt.scatter(x[:,1], y, c='b', label='Data')

plt.legend(loc='best')

plt.xlabel('Square Meters')
plt.ylabel('Price (k)')
plt.show()

# %%
new_x = np.array([[1, 75], [1, 120]])

new_y_hat = new_x.dot(ls)

new_y_hat
# Out:
# array([ 726.38027037, 1262.79511161])

# %%
plt.scatter(x[:,1], y, c='b', label='Data')

x_cat = np.concatenate((x, new_x))
y_hat_cat = np.concatenate((y_hat, new_y_hat))

plt.plot(x_cat[:,1], y_hat_cat, c='g', label='Model')
plt.scatter(new_x[:,1], new_y_hat, c='r')
