# %%
from sklearn.datasets import make_regression

x, y = make_regression(n_samples=100, n_features=1, noise=20)

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.show()

# %%
import numpy as np

x = np.interp(x, (x.min(), x.max()), (20, 80))
y = np.interp(y, (y.min(), y.max()), (100, 800))

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.xlabel('Square Meters')
plt.ylabel('Price (k)')
plt.show()

# %%
x = np.hstack((np.ones(shape=(len(x), 1)), x))

# %% [markdown]
# $$(\mathbf{X}^T\mathbf{X})^{-1}\mathbf{X}^T\mathbf{y}$$

# %%
ls = np.linalg.inv(x.T.dot(x)).dot(x.T).dot(y)

# %%
y_hat = x.dot(ls)
y_hat
# Out:
# array([539.1690481 , 389.65722093, 494.31749753, 458.11581563,
#        297.26853799, 572.86483203, 396.98610408, 562.83226123,
#        408.33988131, 466.21146976, 311.08898716, 479.13450913,
#        651.17380848, 585.51793329, 432.00445359, 548.26218847,
#        333.72128859, 391.97063168, 177.5607012 , 528.14319752,
#        639.11164887, 407.4054802 , 370.78860344, 330.39537172,
#        751.5605583 , 469.44120287, 427.18322384, 426.10327415,
#        407.91992095, 356.01235403, 576.50264749, 573.08963974,
#        250.27056504, 466.76062165, 410.44125921, 366.18510511,
#        371.5354947 , 319.03733463, 378.17624557, 256.63248762,
#        374.37273848, 512.17697918, 331.0095797 , 401.16135144,
#        486.983941  , 723.64281547, 274.16430006, 247.37601698,
#        344.47869791, 320.17514207, 408.00888656, 486.88082696,
#        438.35513688, 430.00799585, 374.12999758, 432.4601156 ,
#        226.30498971, 446.00959656, 415.87322922, 236.47460846,
#        645.49990718, 331.69669689, 473.87819159, 275.53891234,
#        496.77444113, 454.20591202, 338.95555883, 341.52274409,
#        639.38462375, 393.67434933, 411.84255671, 618.36144753,
#        489.58083139, 528.63205467, 512.4316895 , 517.22744594,
#        433.05618528, 416.957692  , 184.27689014, 599.45110475,
#        196.32653979, 103.34666496, 312.2298703 , 182.9941403 ,
#        392.48847273, 649.83002491, 433.52462309, 384.47871799,
#        349.38564333, 418.36344528, 308.8024137 , 355.59071556,
#        557.93804225, 409.69497517, 540.45958275, 520.24267788,
#        342.71597063, 531.99578461, 359.12076788, 388.56971946])

# %%
mse = np.mean((y.flatten() - y_hat)**2)
mse
# Out:
# 6033.754794856891

# %%
plt.plot(x[:,1], y_hat, c='g', label='Model')
plt.scatter(x[:,1], y, c='b', label='Data')

plt.legend(loc='best')

plt.xlabel('Square Meters')
plt.ylabel('Price (k)')
plt.show()

# %%
new_x = np.array([[1, 75], [1, 120]])

new_y_hat = new_x.dot(ls)

new_y_hat
# Out:
# array([ 697.54273385, 1183.70315385])

# %%
plt.scatter(x[:,1], y, c='b', label='Data')

x = np.concatenate((x, new_x))
y_hat = np.concatenate((y_hat, new_y_hat))

plt.plot(x())
